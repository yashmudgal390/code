# %%
import numpy as np
import pandas as pd

# %%
# pd.MultiIndex.from_tuples()
#pd.MultiIndex.from_product()
#multi indexing is also known as hierachical indexing
pd.MultiIndex.from_product([['cse','ese'],[2019,2020,2021,2022]])
# Out:
# MultiIndex([('cse', 2019),
#             ('cse', 2020),
#             ('cse', 2021),
#             ('cse', 2022),
#             ('ese', 2019),
#             ('ese', 2020),
#             ('ese', 2021),
#             ('ese', 2022)],
#            )

# %%
s =  pd.Series([1,2,3,4,5,6,7,8],index=pd.MultiIndex.from_product([['cse','ese'],[2019,2020,2021,2022]]))
s
# Out:
# cse  2019    1
#      2020    2
#      2021    3
#      2022    4
# ese  2019    5
#      2020    6
#      2021    7
#      2022    8
# dtype: int64

# %%
s[['cse']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 s[['cse'][2019]]
#
# IndexError: list index out of range

# %%
temp= s.unstack()
temp
# Out:
#      2019  2020  2021  2022
# cse     1     2     3     4
# ese     5     6     7     8

# %%
temp.stack()
# Out:
# cse  2019    1
#      2020    2
#      2021    3
#      2022    4
# ese  2019    5
#      2020    6
#      2021    7
#      2022    8
# dtype: int64
