# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-10, 10, 100)
y= x

# %%
plt.plot(x,y)

# %%
y=x**2
plt.plot(x,y)

# %%
y=np.sin(x)
plt.plot(x,y)

# %%
y= x*np.log(x)
plt.plot(x,y)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20028\1302608410.py:1: RuntimeWarning: invalid value encountered in log
#   y= x*np.log(x)

# %%
plt.scatter(x,y)

# %%
a = np.random.randint(1,100,15)
a
# Out:
# array([81, 92, 41, 64, 32, 24, 79, 44, 89, 57, 70,  8, 70, 63,  6],
#       dtype=int32)

# %%
a.sort()

# %%
a
# Out:
# array([ 6,  8, 24, 32, 41, 44, 57, 63, 64, 70, 70, 79, 81, 89, 92],
#       dtype=int32)

# %%
b = np.random.randint(1,100,24).reshape(6,4)
b
# Out:
# array([[84, 12, 55, 61],
#        [85, 89,  2, 77],
#        [18, 95, 71, 81],
#        [29, 41,  5, 66],
#        [ 1, 67, 22, 27],
#        [44, 21, 13, 13]], dtype=int32)

# %%
b.sort(axis=0)

# %%
b
# Out:
# array([[ 1, 13, 21, 44],
#        [ 2, 22, 27, 66],
#        [ 5, 29, 41, 67],
#        [12, 55, 61, 84],
#        [13, 71, 81, 89],
#        [18, 77, 85, 95]], dtype=int32)

# %%
import numpy as np 
import matplotlib.pyplot as plt
